# %%
import string
import os
import numpy as np
import tensorflow as tf

from tensorflow import keras
from datetime import datetime, timedelta

# %%
POSSIBLE_INPUT_CHARS = f'{"".join(list(map(str, range(10))))}{string.ascii_lowercase}-'
POSSIBLE_OUTPUT_CHARS = f'{"".join(list(map(str, range(10))))}-'
CURRENT_DAY = datetime.utcnow()
ROW_COUNT = 10000


def string_to_ids(s: str, chars: str) -> list[int]:
    ids = []

    for char in s.lower():
        try:
            idx = chars.index(char)

            ids.append(idx)
        except:
            ids.append(-1)

    return ids


def shuffle(vals: tf.RaggedTensor, targets: tf.RaggedTensor) -> (tf.RaggedTensor, tf.RaggedTensor):
    a = tf.random.shuffle(tf.range(vals.shape[0]))
    b = tf.reshape(a, (vals.shape[0], 1))
    shuffled_vals = tf.gather_nd(vals, b)
    shuffled_targets = tf.gather_nd(targets, b)

    return shuffled_vals, shuffled_targets


def pad_year(year: int) -> str:
    return f'{"".join(map(str, [0] * (4 - len(str(year)))))}{year}'


def get_date_pairs() -> (np.ndarray, np.ndarray):
    xs = []
    ys = []
    all_years = np.arange(ROW_COUNT).tolist()
    years_padded = np.array([pad_year(year) for year in all_years])

    np.random.shuffle(years_padded)

    for counter in range(ROW_COUNT):
        date = CURRENT_DAY - timedelta(days=counter)
        year_month_day = date.strftime('%Y-%m-%d')
        year_month_name_day = date.strftime('%Y-%B-%d')
        _, month_name, day = year_month_name_day.split('-')
        year = years_padded[counter]
        year_month_day = f'{year}-{year_month_day[5:]}'
        xs.append(tf.constant(
            string_to_ids(f'{year}-', POSSIBLE_INPUT_CHARS) +
            string_to_ids(f'{month_name}-', POSSIBLE_INPUT_CHARS) +
            string_to_ids(day, POSSIBLE_INPUT_CHARS)))
        ys.append(tf.constant(string_to_ids(year_month_day, POSSIBLE_OUTPUT_CHARS)))

    ragged_xs = tf.ragged.stack(xs, axis=0)
    ragged_ys = tf.ragged.stack(ys, axis=0)

    return shuffle(ragged_xs, ragged_ys)


X, y = get_date_pairs()
X = (X + 1).to_tensor()
y = y.to_tensor()
seventy_percent_count = int(X.shape[0] * .7)
ninety_percent_count = int(X.shape[0] * .9)
X_train, y_train = X[:seventy_percent_count, :], y[:seventy_percent_count, :]
X_valid, y_valid = X[seventy_percent_count:ninety_percent_count, :], y[seventy_percent_count:ninety_percent_count, :]
X_test, y_test = X[ninety_percent_count:, :], y[ninety_percent_count:, :]

# %%
def run_basic_model(model: keras.Model, name: str, patience: int=5):
    model_dir = os.path.join(os.curdir, 'saved_models')
    run_logdir_root = os.path.join(os.curdir, 'tensor_logs')
    dirs_count = len([
        name
        for name in os.listdir(run_logdir_root)
        if os.path.isdir(os.path.join(run_logdir_root, name)) and name.startswith(name)
    ])
    run_logdir = os.path.join(run_logdir_root, f'{name}_{dirs_count}')
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)
    model_checkpoint = keras.callbacks.ModelCheckpoint(os.path.join(model_dir, f'{name}_{dirs_count}.h5'), save_best_only=True)
    tensorboard = keras.callbacks.TensorBoard(run_logdir, histogram_freq=1, profile_batch=10)

    optimizer = keras.optimizers.Nadam()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

    return model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=40, callbacks=[early_stopping, model_checkpoint, tensorboard])


embedding_size = 32
max_output_length = y.shape[1]

np.random.seed(42)
tf.random.set_seed(42)

# %%
encoder = keras.models.Sequential([
    keras.layers.Embedding(input_dim=len(POSSIBLE_INPUT_CHARS) + 1,
                           output_dim=embedding_size,
                           input_shape=[None]),
    keras.layers.LSTM(128)
])

decoder = keras.models.Sequential([
    keras.layers.LSTM(128, return_sequences=True),
    keras.layers.Dense(len(POSSIBLE_OUTPUT_CHARS) + 1, activation="softmax")
])

model = keras.models.Sequential([
    encoder,
    keras.layers.RepeatVector(max_output_length),
    decoder
])


run_basic_model(model, 'basic_encoder_model_lstm')
# Out:
# Epoch 1/40
# 219/219 [==============================] - 12s 21ms/step - loss: 1.9373 - accuracy: 0.3111 - val_loss: 1.5314 - val_accuracy: 0.4323
# Epoch 2/40
# 219/219 [==============================] - 4s 16ms/step - loss: 1.3532 - accuracy: 0.5083 - val_loss: 1.2108 - val_accuracy: 0.5687
# Epoch 3/40
# 219/219 [==============================] - 3s 16ms/step - loss: 1.2669 - accuracy: 0.5555 - val_loss: 1.7907 - val_accuracy: 0.3659
# Epoch 4/40
# 219/219 [==============================] - 3s 16ms/step - loss: 1.3473 - accuracy: 0.5227 - val_loss: 1.1102 - val_accuracy: 0.5981
# Epoch 5/40
# 219/219 [==============================] - 4s 16ms/step - loss: 1.0449 - accuracy: 0.6158 - val_loss: 1.0234 - val_accuracy: 0.6277
# Epoch 6/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.9245 - accuracy: 0.6563 - val_loss: 0.9140 - val_accuracy: 0.6590
# Epoch 7/40
# 219/219 [==============================] - 4s 16ms/step - loss: 0.7885 - accuracy: 0.7056 - val_loss: 0.7237 - val_accuracy: 0.7271
# Epoch 8/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.6561 - accuracy: 0.7527 - val_loss: 0.6021 - val_accuracy: 0.7721
# Epoch 9/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.7128 - accuracy: 0.7463 - val_loss: 0.5985 - val_accuracy: 0.7743
# Epoch 10/40
# 219/219 [==============================] - 4s 16ms/step - loss: 0.5039 - accuracy: 0.8055 - val_loss: 0.4636 - val_accuracy: 0.8163
# Epoch 11/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.4231 - accuracy: 0.8314 - val_loss: 0.3971 - val_accuracy: 0.8416
# Epoch 12/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.8185 - accuracy: 0.7143 - val_loss: 1.0192 - val_accuracy: 0.6645
# Epoch 13/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.7095 - accuracy: 0.7441 - val_loss: 0.5597 - val_accuracy: 0.7907
# Epoch 14/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.4725 - accuracy: 0.8316 - val_loss: 0.4141 - val_accuracy: 0.8530
# Epoch 15/40
# 219/219 [==============================] - 4s 16ms/step - loss: 0.5285 - accuracy: 0.8274 - val_loss: 0.3715 - val_accuracy: 0.8662
# Epoch 16/40
# 219/219 [==============================] - 4s 16ms/step - loss: 0.3040 - accuracy: 0.8996 - val_loss: 0.2852 - val_accuracy: 0.9024
# Epoch 17/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.2322 - accuracy: 0.9287 - val_loss: 0.2204 - val_accuracy: 0.9312
# Epoch 18/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1742 - accuracy: 0.9516 - val_loss: 0.1636 - val_accuracy: 0.9532
# Epoch 19/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.1381 - accuracy: 0.9647 - val_loss: 0.1290 - val_accuracy: 0.9642
# Epoch 20/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0982 - accuracy: 0.9777 - val_loss: 0.0968 - val_accuracy: 0.9766
# Epoch 21/40
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0733 - accuracy: 0.9849 - val_loss: 0.0771 - val_accuracy: 0.9818
# Epoch 22/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0582 - accuracy: 0.9890 - val_loss: 0.0589 - val_accuracy: 0.9879
# Epoch 23/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0553 - accuracy: 0.9903 - val_loss: 0.0618 - val_accuracy: 0.9863
# Epoch 24/40
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0366 - accuracy: 0.9953 - val_loss: 0.0388 - val_accuracy: 0.9932
# Epoch 25/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0260 - accuracy: 0.9974 - val_loss: 0.0372 - val_accuracy: 0.9924
# Epoch 26/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0202 - accuracy: 0.9983 - val_loss: 0.0306 - val_accuracy: 0.9941
# Epoch 27/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0190 - accuracy: 0.9982 - val_loss: 0.0218 - val_accuracy: 0.9963
# Epoch 28/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0129 - accuracy: 0.9993 - val_loss: 0.0172 - val_accuracy: 0.9976
# Epoch 29/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0107 - accuracy: 0.9993 - val_loss: 0.0163 - val_accuracy: 0.9973
# Epoch 30/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.0137 - val_accuracy: 0.9977
# Epoch 31/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0067 - accuracy: 0.9999 - val_loss: 0.0111 - val_accuracy: 0.9982
# Epoch 32/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.3090 - accuracy: 0.9197 - val_loss: 0.6471 - val_accuracy: 0.7865
# Epoch 33/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.1437 - accuracy: 0.9660 - val_loss: 0.0454 - val_accuracy: 0.9936
# Epoch 34/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0245 - accuracy: 0.9982 - val_loss: 0.0233 - val_accuracy: 0.9972
# Epoch 35/40
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0129 - accuracy: 0.9995 - val_loss: 0.0155 - val_accuracy: 0.9979
# Epoch 36/40
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.0130 - val_accuracy: 0.9983

# %%
encoder = keras.models.Sequential([
    keras.layers.Embedding(input_dim=len(POSSIBLE_INPUT_CHARS) + 1,
                           output_dim=embedding_size,
                           input_shape=[None]),
    keras.layers.GRU(128)
])

decoder = keras.models.Sequential([
    keras.layers.GRU(128, return_sequences=True),
    keras.layers.Dense(len(POSSIBLE_OUTPUT_CHARS) + 1, activation="softmax")
])

model = keras.models.Sequential([
    encoder,
    keras.layers.RepeatVector(max_output_length),
    decoder
])


run_basic_model(model, 'basic_encoder_model_gru')
# Out:
# Epoch 1/40
# 219/219 [==============================] - 7s 18ms/step - loss: 1.8601 - accuracy: 0.3309 - val_loss: 1.4576 - val_accuracy: 0.4476
# Epoch 2/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.3604 - accuracy: 0.4967 - val_loss: 1.2588 - val_accuracy: 0.5451
# Epoch 3/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.2442 - accuracy: 0.5629 - val_loss: 1.1089 - val_accuracy: 0.5983
# Epoch 4/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0519 - accuracy: 0.6184 - val_loss: 0.9750 - val_accuracy: 0.6472
# Epoch 5/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.4267 - accuracy: 0.5040 - val_loss: 1.1672 - val_accuracy: 0.5739
# Epoch 6/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.8824 - accuracy: 0.3348 - val_loss: 1.7878 - val_accuracy: 0.3356
# Epoch 7/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.5423 - accuracy: 0.4457 - val_loss: 1.1306 - val_accuracy: 0.6003
# Epoch 8/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.5159 - accuracy: 0.4551 - val_loss: 2.2569 - val_accuracy: 0.2074
# Epoch 9/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.2085 - accuracy: 0.5569 - val_loss: 0.8449 - val_accuracy: 0.6868
# Epoch 10/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7490 - accuracy: 0.7161 - val_loss: 0.6898 - val_accuracy: 0.7351
# Epoch 11/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.6239 - accuracy: 0.7601 - val_loss: 0.5800 - val_accuracy: 0.7736
# Epoch 12/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.5179 - accuracy: 0.7992 - val_loss: 0.4806 - val_accuracy: 0.8154
# Epoch 13/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.4409 - accuracy: 0.8251 - val_loss: 0.4217 - val_accuracy: 0.8320
# Epoch 14/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.5249 - accuracy: 0.8082 - val_loss: 0.3839 - val_accuracy: 0.8510
# Epoch 15/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.3432 - accuracy: 0.8700 - val_loss: 0.3209 - val_accuracy: 0.8820
# Epoch 16/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.5483 - accuracy: 0.8286 - val_loss: 1.8680 - val_accuracy: 0.3175
# Epoch 17/40
# 219/219 [==============================] - 3s 14ms/step - loss: 1.3209 - accuracy: 0.5063 - val_loss: 0.6997 - val_accuracy: 0.7882
# Epoch 18/40
# 219/219 [==============================] - 3s 13ms/step - loss: 0.4758 - accuracy: 0.8576 - val_loss: 0.3564 - val_accuracy: 0.8937
# Epoch 19/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.5947 - accuracy: 0.8153 - val_loss: 0.5355 - val_accuracy: 0.8181
# Epoch 20/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.3297 - accuracy: 0.9078 - val_loss: 0.2376 - val_accuracy: 0.9384
# Epoch 21/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1832 - accuracy: 0.9592 - val_loss: 0.1597 - val_accuracy: 0.9636
# Epoch 22/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1250 - accuracy: 0.9751 - val_loss: 0.1141 - val_accuracy: 0.9758
# Epoch 23/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0889 - accuracy: 0.9851 - val_loss: 0.0852 - val_accuracy: 0.9842
# Epoch 24/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0646 - accuracy: 0.9909 - val_loss: 0.0632 - val_accuracy: 0.9882
# Epoch 25/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0482 - accuracy: 0.9941 - val_loss: 0.0487 - val_accuracy: 0.9923
# Epoch 26/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0359 - accuracy: 0.9964 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 27/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0275 - accuracy: 0.9977 - val_loss: 0.0294 - val_accuracy: 0.9965
# Epoch 28/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0213 - accuracy: 0.9987 - val_loss: 0.0241 - val_accuracy: 0.9978
# Epoch 29/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0165 - accuracy: 0.9993 - val_loss: 0.0189 - val_accuracy: 0.9984
# Epoch 30/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.4314 - accuracy: 0.8646 - val_loss: 0.3914 - val_accuracy: 0.8779
# Epoch 31/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.1450 - accuracy: 0.9710 - val_loss: 0.0611 - val_accuracy: 0.9947
# Epoch 32/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0376 - accuracy: 0.9983 - val_loss: 0.0325 - val_accuracy: 0.9980
# Epoch 33/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0219 - accuracy: 0.9995 - val_loss: 0.0227 - val_accuracy: 0.9984
# Epoch 34/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0151 - accuracy: 0.9998 - val_loss: 0.0166 - val_accuracy: 0.9992
# Epoch 35/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0112 - accuracy: 0.9999 - val_loss: 0.0130 - val_accuracy: 0.9995
# Epoch 36/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9997
# Epoch 37/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9998
# Epoch 38/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9999
# Epoch 39/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9998
# Epoch 40/40
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9999

# %%
def ids_to_date_strs(ids: list[int]) -> str:
    year = ids[:4]
    day = ids[(4 + 4):]
    kind_of_month = ids[4:(4 + 4)]

    return f'{"".join(map(str, year))}{POSSIBLE_OUTPUT_CHARS[kind_of_month[0]]}{POSSIBLE_OUTPUT_CHARS[kind_of_month[1]]}{POSSIBLE_OUTPUT_CHARS[kind_of_month[2]]}{POSSIBLE_OUTPUT_CHARS[kind_of_month[3]]}{"".join(map(str, day))}'


def zero_pad_right(vec: list[int], max_length: int) -> list[int]:
    return vec + [0] * (max_length - len(vec))

# %%
X_new = [zero_pad_right(list(map(lambda n: n + 1, string_to_ids(date_str, POSSIBLE_INPUT_CHARS))), X.shape[1]) for date_str in ['1999-June-30', '1874-September-08']]
chosen_ids_array = np.argmax(model.predict(X_new), axis=-1)

for row in chosen_ids_array:
    print(ids_to_date_strs(row.tolist()))
# Out:
# 1/1 [==============================] - 1s 507ms/step
# 1999-06-30
# 1874-09-08
